# %%
import pandas as pd

# %%
crop_prod = pd.read_csv("../data/crop_production.csv")
all_ind = pd.read_csv("../data/all_india.csv")
dist_rain = pd.read_csv("../data/district wise rainfall normal.csv")
rain_ind = pd.read_csv("../data/rainfall in india 1901-2015.csv")

# %% [markdown]
# CROP Production Data

# %%
crop_prod.describe()
# Out:
#            Crop_Year          Area    Production
# count  246091.000000  2.460910e+05  2.423610e+05
# mean     2005.643018  1.200282e+04  5.825034e+05
# std         4.952164  5.052340e+04  1.706581e+07
# min      1997.000000  4.000000e-02  0.000000e+00
# 25%      2002.000000  8.000000e+01  8.800000e+01
# 50%      2006.000000  5.820000e+02  7.290000e+02
# 75%      2010.000000  4.392000e+03  7.023000e+03
# max      2015.000000  8.580100e+06  1.250800e+09

# %%
crop_prod.isnull().sum() # prodcolumn has null value
# Out:
# State_Name          0
# District_Name       0
# Crop_Year           0
# Season              0
# Crop                0
# Area                0
# Production       3730
# dtype: int64

# %% [markdown]
# Checking incosisteance in categorical data

# %%
crop_prod.dtypes
# Out:
# State_Name           str
# District_Name        str
# Crop_Year          int64
# Season               str
# Crop                 str
# Area             float64
# Production       float64
# dtype: object

# %%
crop_prod.duplicated().sum()
# Out:
# np.int64(0)

# %%
string_cols = crop_prod.select_dtypes(include=['object','string']).columns
for i in string_cols:
    inconsistent_value =crop_prod[i]!=crop_prod[i].str.strip()
    inconsistent_value=crop_prod[inconsistent_value][i].unique()
    if len(inconsistent_value) > 0:
        print(f"Cols {i}")
        print(f"vale {inconsistent_value}")
# Out:
# Cols State_Name
# vale <StringArray>
# ['Jammu and Kashmir ', 'Telangana ']
# Length: 2, dtype: str
# Cols Season
# vale <StringArray>
# ['Kharif     ', 'Whole Year ', 'Autumn     ', 'Rabi       ', 'Summer     ',
#  'Winter     ']
# Length: 6, dtype: str
# Cols Crop
# vale <StringArray>
# ['Coconut ']
# Length: 1, dtype: str

# %% [markdown]
# All INDIA Data preprocessing and data exploration

# %%
all_ind.dtypes
# Out:
# state             str
# district          str
# market            str
# commodity         str
# variety           str
# arrival_date      str
# min_price       int64
# max_price       int64
# modal_price     int64
# dtype: object

# %%
all_ind
# Out:
#                     state        district      market              commodity  \
# 0     Andaman and Nicobar   South Andaman  Port Blair             Amaranthus
# 1     Andaman and Nicobar   South Andaman  Port Blair         Banana - Green
# 2     Andaman and Nicobar   South Andaman  Port Blair  Bhindi(Ladies Finger)
# 3     Andaman and Nicobar   South Andaman  Port Blair           Bitter gourd
# 4     Andaman and Nicobar   South Andaman  Port Blair           Black pepper
# ...                   ...             ...         ...                    ...
# 2233          West Bengal  Uttar Dinajpur    Islampur                 Potato
# 2234          West Bengal  Uttar Dinajpur    Islampur                   Rice
# 2235          West Bengal  Uttar Dinajpur     Raiganj                   Jute
# 2236          West Bengal  Uttar Dinajpur     Raiganj                   Rice
# 2237          West Bengal  Uttar Dinajpur     Raiganj                  Wheat
#
# ...

# %%
all_ind.isnull().sum() # no null values
# Out:
# state           0
# district        0
# market          0
# commodity       0
# variety         0
# arrival_date    0
# min_price       0
# max_price       0
# modal_price     0
# dtype: int64

# %%
# duplicate exists
all_ind.duplicated().sum()
# Out:
# np.int64(2)

# %%
ind_col = all_ind.select_dtypes(include=["str","object"]).columns
for cols in ind_col:
    in_value = all_ind[cols] != all_ind[cols].str.strip()
    in_value = all_ind[in_value][cols].unique()
    if len(in_value) > 0:
        print(f" COl {cols}")
        print(f"vales{in_value}") # one column with inconsitent data
# Out:
#  COl variety
# vales<StringArray>
# [' Subabul']
# Length: 1, dtype: str

# %% [markdown]
# Rain data Processing

# %%
# dist_rain Hold feature

# %%
rain_ind
# Out:
#                     SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0     ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1     ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2     ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3     ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4     ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
# ...                         ...   ...   ...    ...   ...    ...    ...    ...
# 4111                LAKSHADWEEP  2011   5.1    2.8   3.1   85.9  107.2  153.6
# 4112                LAKSHADWEEP  2012  19.2    0.1   1.6   76.8   21.2  327.0
# 4113                LAKSHADWEEP  2013  26.2   34.4  37.5    5.3   88.3  426.2
# 4114                LAKSHADWEEP  2014  53.2   16.1   4.4   14.9   57.4  244.1
# 4115                LAKSHADWEEP  2015   2.2    0.5   3.7   87.1  133.1  296.6
#
# ...

# %%
rain_ind.isnull().sum()
# Out:
# SUBDIVISION     0
# YEAR            0
# JAN             4
# FEB             3
# MAR             6
# APR             4
# MAY             3
# JUN             5
# JUL             7
# AUG             4
# SEP             6
# OCT             7
# NOV            11
# DEC            10
# ANNUAL         26
# Jan-Feb         6
# Mar-May         9
# Jun-Sep        10
# Oct-Dec        13
# dtype: int64

# %%
rain_ind.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4116 entries, 0 to 4115
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   SUBDIVISION  4116 non-null   str
#  1   YEAR         4116 non-null   int64
#  2   JAN          4112 non-null   float64
#  3   FEB          4113 non-null   float64
#  4   MAR          4110 non-null   float64
#  5   APR          4112 non-null   float64
#  6   MAY          4113 non-null   float64
#  7   JUN          4111 non-null   float64
#  8   JUL          4109 non-null   float64
#  9   AUG          4112 non-null   float64
#  10  SEP          4110 non-null   float64
#  11  OCT          4109 non-null   float64
#  12  NOV          4105 non-null   float64
#  13  DEC          4106 non-null   float64
#  14  ANNUAL       4090 non-null   float64
#  15  Jan-Feb      4110 non-null   float64
#  16  Mar-May      4107 non-null   float64
#  17  Jun-Sep      4106 non-null   float64
# ...

# %%
rain_ind.describe()
# Out:
#               YEAR          JAN          FEB          MAR          APR  \
# count  4116.000000  4112.000000  4113.000000  4110.000000  4112.000000
# mean   1958.218659    18.957320    21.805325    27.359197    43.127432
# std      33.140898    33.585371    35.909488    46.959424    67.831168
# min    1901.000000     0.000000     0.000000     0.000000     0.000000
# 25%    1930.000000     0.600000     0.600000     1.000000     3.000000
# 50%    1958.000000     6.000000     6.700000     7.800000    15.700000
# 75%    1987.000000    22.200000    26.800000    31.300000    49.950000
# max    2015.000000   583.700000   403.500000   605.600000   595.100000
#
#                MAY          JUN          JUL          AUG          SEP  \
# count  4113.000000  4111.000000  4109.000000  4112.000000  4110.000000
# mean     85.745417   230.234444   347.214334   290.263497   197.361922
# std     123.234904   234.710758   269.539667   188.770477   135.408345
# ...

# %%
rain_ind.duplicated().sum()
# Out:
# np.int64(0)

# %%
# inconsistenet data
rain_cols = rain_ind.select_dtypes(include=["str","object"]).columns
for cols in rain_cols:
    in_value = rain_ind[cols] != rain_ind[cols].str.strip()
    in_value = rain_ind[in_value][cols].unique()
    if len(in_value) > 0:
        print(f"col {cols}")
        print(f"val {in_value}")
